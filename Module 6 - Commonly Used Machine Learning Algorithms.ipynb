# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split, GridSearchCV
from IPython import display

# %%
bank_df = pd.read_csv('train.csv', parse_dates=['DOB', 'Lead_Creation_Date'])

# %%
y = bank_df['Approved']
X = bank_df.drop(['Approved'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=34)

# %% [markdown]
# ### Regression Algorithms

# %% [markdown]
# 1. Linear Regression

# %%
from sklearn import linear_model

reg_model = linear_model.LinearRegression()

reg_model.fit(X_train, y_train)

y_pred = reg_model.predict(X_test)

# %% [markdown]
# 2. KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_model = KNeighborsRegressor(n_neighbors=k, weights='distance')

knn_model.fit(X_train, y_train)

knn_predictions = knn_model.predict(X_test)

# %% [markdown]
# 3. Support Vector Regression

# %%
from sklearn.svm import SVR

svr_model = SVR()

best_svr_model = GridSearchCV(svr_model, param_grid={'C': [0.1, 1,10,100,1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
                              scoring='neg_mean_squared_error', cv=5, n_jobs=-1)
                              
best_svr_model.fit(X_train, y_train)

best_svr_model.best_params_

final_svr_model = SVR(C=10, gamma=0.01)

# %% [markdown]
# 4. Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest = RandomForestRegressor(n_estimators= 100, random_state=204)

random_forest.fit(X_train, y_train)

# %% [markdown]
# 5. XGBoost

# %%
from xgboost import XGBRegressor as xgbr

xgbm = xgbr()

xgbr.fit(X_train, y_train)

# %% [markdown]
# #### Commonly used metrics to evaluate Regression Models
#
# 1. Mean Absolute Error(MAE)
# 2. Mean Squared Error(MSE)
# 3. Root Mean Squared Error (RMSE)
# 4. Roor Mean Squared Log Error (RMSLE)
# 5. R squared (R2)
# 6. Adjusted R Squared

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### Classification Algorithms

# %% [markdown]
# 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logit_model = LogisticRegression(class_weight='balanced', random_state=204)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=204)

best_logit = GridSearchCV(logit_model, param_grid={'max_iter':[100,300,500,1000], 'C':[0.001, 0.01, 0.1, 1, 10, 100, 1000]}, 
                          scoring='roc_auc', cv=kfold, n_jobs=-1)

best_logit.fit(X_train, y_train_logit)

best_logit.best_params_

# %% [markdown]
# 2. Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

naive_model = GaussianNB()

naive_model.fit(X_train, y_train)

naive_predictions = naive_model.predict(X_test)

# %% [markdown]
# 3. Support Vector Machine

# %%
from sklearn.svm import SVC

# %% [markdown]
# 4. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# 5. XGBoost

# %%
from xgboost import XGBClassifier

# %% [markdown]
# <b>Commonly used metrics to evaluate Classification Models</b>

# %% [markdown]
# 1. Accuracy
# 2. Confusion Matrix
#     1. Precsion
#     2. Recall
#     3. F1 Score
# 3. AUC-ROC
# 4. Log - Loss

# %%
from sklearn.metrics import classification_report

# %%
display.Image('Confusion_Matrix.PNG', width=500, height=500)

# %%
display.Image('Precision.PNG', width=500, height=500)

# %%
display.Image('Recall.PNG', width=500, height=500)
