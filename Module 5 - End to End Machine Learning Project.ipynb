# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as viz
import seaborn as sb
from IPython import display

# %% [markdown]
# ### Getting the Summary of Data

# %% [markdown]
# ### 5.1 Data Imputation

# %% [markdown]
# <b>Mean/Median</b>
#
# 1. This imputation is applicable to Numeric Values columns
# 2. To decide between mean and median, you need to look at the distribution of data.
# 3. Distribution is Normal - Mean Imputation
# 4. Distribution is Skewed - Median Imputation

# %% [markdown]
# <b>Mode/Most Frequent</b>
#
# 1. This imputation is applicable to categorical Values columns
#
# <b>Pro: </b> Easy and Fast
#
# <b>Con: </b>Doesn't consider the correlations between features and introduce bias

# %% [markdown]
# <b>Other Advanced Imputation Techniques</b>
#
# 1. k-NN Imputation
# 2. Multivariate Imputation by Chained Equation (MICE)
# 3. Iterative Imputation
# 3. Timeseries Imputation - Backfill and Forwardfill

# %%
from fancyimpute import KNN

# %%
from sklearn.impute import IterativeImputer

# %% [markdown]
# ### 5.2 Data Type Conversion

# %% [markdown]
# The data type of the column has to be converted to suitable type before using the raw format.
#
# 1. String -> Numeric
# 2. Date -> Numeric
# 3. Categorical -> Numeric
# 4. Numeric -> Categorical

# %% [markdown]
# ### 5.3 Outlier Treatment

# %% [markdown]
# Outliers are those data points which differs significantly from other observations present in given dataset. An outlier may occur due to the variability in the data, or due to experimental error/human error.
#
# <b>Steps</b>
#
# 1. Identify the Outlier by Statitical methods / Visualization

# %% [markdown]
# <b>a. Z-Score</b>

# %%
display.Image('Z-Score.PNG', width=400, height=400)

# %% [markdown]
# <b>b. Inter Quantile Range (IQR)</b>

# %%
display.Image('IQR.PNG', width=500, height=500)

# %% [markdown]
# <b>c. Box-Plot</b>

# %%
display.Image('Box_Plot.png', width=500, height=500)

# %% [markdown]
# Adavanced Outlier Treatment
#
#     1. DBSCAN
#     2. Local Outlier Factor
#     3. Isolation Forest

# %% [markdown]
# 2. Treat the Outliers
#
#
#     1. Deleting observations - If the number of outliers are small, you can delete the observation from the dataset
#
#     2. Transforming the values
#
#         1. Scaling
#         2. Log transformation
#         3. Cube Root Normalization
#         4. Box-transformation

# %%
display.Image('Log_Transformation.png', width=500, height=500)

# %% [markdown]
#     3. Imputing with Median Values
#
#     Remove the original value present in the dataset and impute with the median value of the data.

# %% [markdown]
# ### 5.4 Feature Scaling

# %% [markdown]
# Feature Scaling is a technique to standardize the independent features present in the data in a fixed range. Many machine learning algorithms that are using Euclidean distance (or) other distance metrics to calculate the similarities will fail to give a reasonable recognition to the smaller feature in presence of the feature having wide range.
#
# Top 5 Feature Scaling Techniques
#
# 1. Absolute Maximum Scaling
# 2. Min-Max Scaling
# 3. Normalization
# 4. Standardization
# 5. Robust Scaling

# %%
display.Image('Feature_Scaling.png', width=500, height=500)

# %% [markdown]
# ### 5.5 Feature Selection

# %% [markdown]
# Feature Selection is the method of reducing the input variable to your model by using only relevant data and getting rid of noise in data. The feature selection rely heavily on the domain expertise of the person working on the project.
#
# Most Commonly Used Feature Selection Techniques
#
# 1. Chi-Square Test
# 2. Correlation Coefficient
# 3. Mean Absolute Difference (MAD)
#
# Advanced Feature Selection Techniques
#
# 1. Forward Selection Techniques
# 2. Backward Selection Techniques
# 3. Random Forest Importance

# %%
display.Image('Feature_Selection.png', width=500, height=500)

# %% [markdown]
# ### 5.6 Encoding of data

# %% [markdown]
# Encoding is a technique of converting categorical variables into numerical values
#
# Most Commonly Used Encoding Techniques
#
# 1. Binary Encoding
# 2. One-Hot Encoding

# %%
display.Image('One-Hot_Encoding.PNG', width=500, height=500)

# %% [markdown]
# 3. Ordinal Encoding

# %%
display.Image('Ordinal_Encoding.png', width=200, height=200)

# %% [markdown]
# 4. Frequency Encoding - frequency(category)/size(data)

# %%
display.Image('Frequency_Encoding.PNG', width=500, height=500)

# %% [markdown]
# 5. Label Encoding

# %%
display.Image('Label_Encoding.png', width=500, height=500)

# %% [markdown]
# ### 5.7 Splitting of Data

# %% [markdown]
# Data is split into Training Set, Validation Set and Test Set
#
# Machine Learning - 80:10:10 (or) 70:20:10
#
# Deep Learning - 98:1:1
